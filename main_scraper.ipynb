# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import requests
import shutil
import time
import os
import json
import pandas as pd
import csv
import shlex


# #Storing Links
# result = requests.get("https://www.bigbasket.com/product/all-categories/")
# #print(result.headers)
# source = result.content
# soup = bs(source, 'html5lib')
# links = soup.find_all("a")
# urls = []
# for link in links:
#     url = link.get('href')
#     if url and "/pc/" in url:
#         #urls.append("https://www.bigbasket.com" + url)
#         urls.append(url)
# urlsx = str(urls)
# for i,x in enumerate(urlsx):
#     urlsx.split('/')
#     print(urlsx)
# #print([i.split('/', 1)[0] for i in urls])
# # import numpy as np
# # final_list = np.array(urls)
# df2 = pd.DataFrame(urls)
# print(df2)
# # df.to_csv('bigbasket_data.csv', index = False)
# # df.to_json('bigbasket.json', orient = 'records')


driver = webdriver.Chrome() # With Head
# chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument('--headless')
# chrome_options.add_argument('--no-sandbox')
# driver = webdriver.Chrome()


links = open('links1.txt', 'r')
url_list = links.readlines()
# print(url_list)
# exit()
check_123 = []
final_links = []
for url in url_list[10:15]:

    driver.get(url)
    # driver.get(url.replace('\n', ''))
    time.sleep(8)   # 2 Sec for ssh
    while True:
        try:
            driver.find_element_by_xpath("//button[@ng-click='vm.pagginator.showmorepage()']").click()
            time.sleep(2)
            print("Clicked Successfully")
        except:
            break
    
    html = driver.execute_script("return document.documentElement.outerHTML")
    soup = bs(html, 'html.parser')
    products = soup.findAll("div", {"qa": "product"})
    # print(len(products))
#     directory = 'All_Data\\' + url.replace('https://www.bigbasket.com/pc/', '').replace('/?nc=bt\n', '').replace('/?nc=nb\n', '').replace('/?nc=cs\n', '').replace('/', '\\')
#     # print(directory)
#     try:
#         os.makedirs(directory+'\\images\\large')
#     except FileExistsError:
#         pass
#     try:
#         os.makedirs(directory + '\\images\\small')
#     except FileExistsError:
#         pass
#     # d_dir = os.path.join(directory, 'data')     # Data Directory
#     data = open(os.path.join(directory, 'data.txt'), "w")
#     data.write("[")
#     # print(directory)
    
    
    
     
    
    
    
    for product in products:
        
        
        #for i, link in enumerate(csv_reader):
        linksy = str(url)
        #[links.split('/', 100)[0] for link in links]
        linksx = str.split(linksy, '/')
        #print(linksx)
        #[linksx.split('/pc/', 100)[0] for link in linksx]
        #print(linksx)
        final_links.append(linksx)
    
    
    
        # break
#         img = product.find("img")['src']
#         image_small = img.replace('/media/uploads/p/mm/', '/media/uploads/p/s/')
#         image_large = img.replace('/media/uploads/p/s/', '/media/uploads/p/l/').replace('/media/uploads/p/mm/', '/media/uploads/p/l/')
#         del img

        Brand = product.find("div", {"qa": "product_name"}).find("h6").text
        Product = product.find("div", {"qa": "product_name"}).find("a").text
        Quantity = product.find("span", {"data-bind": "label"}).text
        Price = product.find("span", {"ng-bind": "vm.selectedProduct.sp.replace('.00', '')"}).text
        try:
            MRP = product.find("span", {"ng-bind": "vm.selectedProduct.mrp.replace('.00', '')"}).text
            #print(MRP)
        except:
            MRP = Price
        hit_list = [Brand, Product, Quantity, Price, MRP]
        check_123.append(hit_list)
#         df=pd.DataFrame(hit_list)
#         df.columns =['Product']
#         df.index = ['Brand', 'Product', 'Quantity', 'Price','MRP']
#         df_1 = df.T

        # Writing data jo json file
#         data.write(json.dumps({
#             'image': [{'small': image_small}, {'large': image_large}],
#             'Brand': Brand,
#             'Product': Product,
#             'Quantity': Quantity,
#             'Price': Price,
#             'M.R.P.': MRP
#         })+',\n\n')

        # copy image files
#         try:
#             image_small_raw = requests.get(image_small, stream=True)
#             filename = os.path.basename(image_small)
#             img_dir = os.path.join(directory, "images\\small", filename)
#             with open(img_dir, "wb") as out_file:
#                 shutil.copyfileobj(image_small_raw.raw, out_file)
#             del image_small_raw

#             image_large_raw = requests.get(image_large, stream=True)
#             time.sleep(1)
#             #print(type(image_small_raw.raw))
#             filename = os.path.basename(image_large)
#             img_dir = os.path.join(directory, "images\\large", filename)
#             with open(img_dir, "wb") as out_file:
#                 shutil.copyfileobj(image_large_raw.raw, out_file)
#             del image_large_raw
#         except Exception as e:
#             print(e)
#         else:
#             pass 
#             #print("Downloaded", url)
#         from tabulate import tabulate
#         pretty_link = tabulate(df_1, headers=['Category', 'Brand','Product', 'Quantity', 'Price'])
#         print(pretty_link)
#     data.write("]")
#     data.close()
   
#final_links.pop(0)
#print(final_links)
df1=pd.DataFrame(final_links,columns=['Domain','Site','S.No', 'Des','Main', 'Sub', 'Sub-Sub', "Link Type"])
del df1['S.No']
del df1['Site']
del df1['Domain']
del df1['Link Type']
del df1['Des']
df1["Sub-Sub"].replace({"']": "None", "?nc=cs']": "None", "?nc=nb']": "None","?nc=nb\n": "None","?nc=bt\n": "None", "?nc=nb": "None" }, inplace=True)
#df1[1:3]
  
    
    
df=pd.DataFrame(check_123, columns= ['Brand', 'Product', 'Quantity','Price','MRP'])
# df.columns =['Product']
# df.index = ['Brand', 'Product', 'Quantity', 'Price']
driver.quit()
links.close()
result = pd.concat([df1, df], axis=1)
result['Price'] = result['Price'].astype(float)
result['MRP'] = result['MRP'].astype(float)
result
#result.to_csv('final_data.csv', index = False)
