# %%
import json
import csv
import shlex
import pandas as pd
with open('bigbasket_data.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    final_links = []
    for i, link in enumerate(csv_reader):
        links = str(link)
        #[links.split('/', 100)[0] for link in links]
        linksx = str.split(links, '/')
        #print(linksx)
        #[linksx.split('/pc/', 100)[0] for link in linksx]
        #print(linksx)
        final_links.append(linksx)
#print(final_links)
df=pd.DataFrame(final_links,columns=['S.No', 'Des','Main', 'Sub', 'Sub-Sub','Link Type'])
#print(df)
#df.to_csv('bigbasket_data_tabular.csv', index = False)
from tabulate import tabulate
pretty_link = tabulate(final_links, headers=['S.No', 'Des','Main', 'Sub', 'Sub-Sub','Link Type'])
print(pretty_link)
# Out:
# S.No                    Des    Main                   Sub                        Sub-Sub                          Link Type
# ----------------------  -----  ---------------------  -------------------------  -------------------------------  -----------
# ['Category Reference']
# ['                      pc     fruits-vegetables      fresh-vegetables           ']
# ['                      pc     fruits-vegetables      fresh-vegetables           potato-onion-tomato              ']
# ['                      pc     fruits-vegetables      fresh-vegetables           leafy-vegetables                 ']
# ['                      pc     fruits-vegetables      fresh-vegetables           root-vegetables                  ']
# ['                      pc     fruits-vegetables      fresh-vegetables           cucumber-capsicum                ']
# ['                      pc     fruits-vegetables      fresh-vegetables           cabbage-cauliflower              ']
# ['                      pc     fruits-vegetables      fresh-vegetables           beans-brinjals-okra              ']
# ['                      pc     fruits-vegetables      fresh-vegetables           gourd-pumpkin-drumstick          ']
# ['                      pc     fruits-vegetables      fresh-vegetables           specialty                        ']
# ['                      pc     fruits-vegetables      herbs-seasonings           ']
# ['                      pc     fruits-vegetables      herbs-seasonings           lemon-ginger-garlic              ']
# ['                      pc     fruits-vegetables      herbs-seasonings           indian-exotic-herbs              ']
# ['                      pc     fruits-vegetables      fresh-fruits               ']
# ['                      pc     fruits-vegetables      fresh-fruits               mangoes                          ']
# ['                      pc     fruits-vegetables      fresh-fruits               banana-sapota-papaya             ']
# ['                      pc     fruits-vegetables      fresh-fruits               kiwi-melon-citrus-fruit          ']
# ['                      pc     fruits-vegetables      fresh-fruits               apples-pomegranate               ']
# ['                      pc     fruits-vegetables      fresh-fruits               seasonal-fruits                  ']
# ['                      pc     fruits-vegetables      fresh-fruits               fruit-baskets                    ']
# ['                      pc     fruits-vegetables      exotic-fruits-veggies      ']
# ['                      pc     fruits-vegetables      exotic-fruits-veggies      exotic-fruits                    ']
# ['                      pc     fruits-vegetables      exotic-fruits-veggies      exotic-vegetables                ']
# ['                      pc     fruits-vegetables      organic-fruits-vegetables  ']
# ['                      pc     fruits-vegetables      organic-fruits-vegetables  organic-vegetables               ']
# ['                      pc     fruits-vegetables      organic-fruits-vegetables  organic-fruits                   ']
# ['                      pc     fruits-vegetables      cuts-sprouts               ']
# ['                      pc     fruits-vegetables      cuts-sprouts               cut-fruit-tender-coconut         ']
# ['                      pc     fruits-vegetables      cuts-sprouts               cut-peeled-veggies               ']
# ['                      pc     fruits-vegetables      cuts-sprouts               fresh-salads-sprouts             ']
# ['                      pc     fruits-vegetables      cuts-sprouts               recipe-packs                     ']
# ['                      pc     fruits-vegetables      flower-bouquets-bunches    ']
# ['                      pc     fruits-vegetables      flower-bouquets-bunches    marigold                         ']
# ['                      pc     fruits-vegetables      flower-bouquets-bunches    other-flowers                    ']
# ['                      pc     fruits-vegetables      flower-bouquets-bunches    roses                            ']
# ['                      pc     foodgrains-oil-masala  atta-flours-sooji          ']
# ['                      pc     foodgrains-oil-masala  atta-flours-sooji          atta-whole-wheat                 ']
# ['                      pc     foodgrains-oil-masala  atta-flours-sooji          sooji-maida-besan                ']
# ['                      pc     foodgrains-oil-masala  atta-flours-sooji          rice-other-flours                ']
# ['                      pc     foodgrains-oil-masala  dals-pulses                ']
# ['                      pc     foodgrains-oil-masala  dals-pulses                toor-channa-moong-dal            ']
# ['                      pc     foodgrains-oil-masala  dals-pulses                cereals-millets                  ']
# ['                      pc     foodgrains-oil-masala  dals-pulses                urad-other-dals                  ']
# ['                      pc     foodgrains-oil-masala  rice-rice-products         ']
# ['                      pc     foodgrains-oil-masala  rice-rice-products         raw-rice                         ']
# ['                      pc     foodgrains-oil-masala  rice-rice-products         poha-sabudana-murmura            ']
# ['                      pc     foodgrains-oil-masala  rice-rice-products         boiled-steam-rice                ']
# ['                      pc     foodgrains-oil-masala  rice-rice-products         basmati-rice                     ']
# ['                      pc     foodgrains-oil-masala  organic-staples            ']
# ['                      pc     foodgrains-oil-masala  organic-staples            organic-dry-fruits               ']
# ['                      pc     foodgrains-oil-masala  organic-staples            organic-dals-pulses              ']
# ['                      pc     foodgrains-oil-masala  organic-staples            organic-sugar-jaggery            ']
# ['                      pc     foodgrains-oil-masala  organic-staples            organic-flours                   ']
# ['                      pc     foodgrains-oil-masala  organic-staples            organic-rice-other-rice          ']
# ['                      pc     foodgrains-oil-masala  organic-staples            organic-edible-oil-ghee          ']
# ['                      pc     foodgrains-oil-masala  organic-staples            organic-masalas-spices           ']
# ['                      pc     foodgrains-oil-masala  salt-sugar-jaggery         ']
# ['                      pc     foodgrains-oil-masala  salt-sugar-jaggery         sugar-jaggery                    ']
# ['                      pc     foodgrains-oil-masala  salt-sugar-jaggery         salts                            ']
# ['                      pc     foodgrains-oil-masala  salt-sugar-jaggery         sugarfree-sweeteners             ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           blended-cooking-oils             ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           gingelly-oil                     ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           sunflower-rice-bran-oil          ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           ghee-vanaspati                   ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           soya-mustard-oils                ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           other-edible-oils                ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           olive-canola-oils                ']
# ['                      pc     foodgrains-oil-masala  edible-oils-ghee           gingelly-groundnut-oils          ']
# ['                      pc     foodgrains-oil-masala  masalas-spices             ']
# ['                      pc     foodgrains-oil-masala  masalas-spices             whole-spices                     ']
# ['                      pc     foodgrains-oil-masala  masalas-spices             powdered-spices                  ']
# ['                      pc     foodgrains-oil-masala  masalas-spices             cooking-pastes                   ']
# ['                      pc     foodgrains-oil-masala  masalas-spices             herbs-seasoning                  ']
# ['                      pc     foodgrains-oil-masala  masalas-spices             blended-masalas                  ']
# ['                      pc     foodgrains-oil-masala  dry-fruits                 ']
# ['                      pc     foodgrains-oil-masala  dry-fruits                 almonds                          ']
# ['                      pc     foodgrains-oil-masala  dry-fruits                 raisins                          ']
# ['                      pc     foodgrains-oil-masala  dry-fruits                 cashews                          ']
# ['                      pc     foodgrains-oil-masala  dry-fruits                 other-dry-fruits                 ']
# ['                      pc     foodgrains-oil-masala  dry-fruits                 mukhwas                          ']
# ['                      pc     bakery-cakes-dairy     dairy                      ']
# ['                      pc     bakery-cakes-dairy     dairy                      milk                             ']
# ['                      pc     bakery-cakes-dairy     dairy                      curd                             ']
# ['                      pc     bakery-cakes-dairy     dairy                      paneer-tofu-cream                ']
# ['                      pc     bakery-cakes-dairy     dairy                      butter-margarine                 ']
# ['                      pc     bakery-cakes-dairy     dairy                      condensed-powdered-milk          ']
# ['                      pc     bakery-cakes-dairy     dairy                      buttermilk-lassi                 ']
# ['                      pc     bakery-cakes-dairy     dairy                      cheese                           ']
# ['                      pc     bakery-cakes-dairy     dairy                      flavoured-soya-milk              ']
# ['                      pc     bakery-cakes-dairy     dairy                      yogurt-shrikhand                 ']
# ['                      pc     bakery-cakes-dairy     breads-buns                ']
# ['                      pc     bakery-cakes-dairy     breads-buns                brown-wheat-multigrain           ']
# ['                      pc     bakery-cakes-dairy     breads-buns                milk-white-sandwich              ']
# ['                      pc     bakery-cakes-dairy     breads-buns                buns-pavs-pizza-base             ']
# ['                      pc     bakery-cakes-dairy     cookies-rusk-khari         ']
# ['                      pc     bakery-cakes-dairy     cookies-rusk-khari         rusks                            ']
# ['                      pc     bakery-cakes-dairy     cookies-rusk-khari         khari-cream-rolls                ']
# ['                      pc     bakery-cakes-dairy     cookies-rusk-khari         bakery-biscuits-cookies          ']
# ['                      pc     bakery-cakes-dairy     cookies-rusk-khari         premium-cookies                  ']
# ['                      pc     bakery-cakes-dairy     gourmet-breads             ']
# ['                      pc     bakery-cakes-dairy     gourmet-breads             croissants-bagels                ']
# ['                      pc     bakery-cakes-dairy     gourmet-breads             gourmet-bread                    ']
# ['                      pc     bakery-cakes-dairy     gourmet-breads             bagels-baguette                  ']
# ['                      pc     bakery-cakes-dairy     gourmet-breads             panini-focaccia-pita             ']
# ['                      pc     bakery-cakes-dairy     ice-creams-desserts        ']
# ['                      pc     bakery-cakes-dairy     ice-creams-desserts        ice-creams                       ']
# ['                      pc     bakery-cakes-dairy     bakery-snacks              ']
# ['                      pc     bakery-cakes-dairy     bakery-snacks              cheese-garlic-bread              ']
# ['                      pc     bakery-cakes-dairy     bakery-snacks              bread-sticks-lavash              ']
# ['                      pc     bakery-cakes-dairy     bakery-snacks              puffs-patties-sandwiches         ']
# ['                      pc     bakery-cakes-dairy     cakes-pastries             ']
# ['                      pc     bakery-cakes-dairy     cakes-pastries             tea-cakes-slice-cakes            ']
# ['                      pc     bakery-cakes-dairy     cakes-pastries             muffins-cup-cakes                ']
# ['                      pc     bakery-cakes-dairy     cakes-pastries             pastries-brownies                ']
# ['                      pc     bakery-cakes-dairy     cakes-pastries             birthday-party-cakes             ']
# ['                      pc     bakery-cakes-dairy     cakes-pastries             doughnuts-mousses                ']
# ['                      pc     beverages              energy-soft-drinks         ']
# ['                      pc     beverages              energy-soft-drinks         soda-cocktail-mix                ']
# ['                      pc     beverages              energy-soft-drinks         cold-drinks                      ']
# ['                      pc     beverages              energy-soft-drinks         sports-energy-drinks             ']
# ['                      pc     beverages              energy-soft-drinks         non-alcoholic-drinks             ']
# ['                      pc     beverages              water                      ']
# ['                      pc     beverages              water                      packaged-water                   ']
# ['                      pc     beverages              water                      spring-water                     ']
# ['                      pc     beverages              water                      flavoured-water                  ']
# ['                      pc     beverages              tea                        ']
# ['                      pc     beverages              tea                        leaf-dust-tea                    ']
# ['                      pc     beverages              tea                        green-tea                        ']
# ['                      pc     beverages              tea                        tea-bags                         ']
# ['                      pc     beverages              tea                        exotic-flavoured-tea             ']
# ['                      pc     beverages              coffee                     ']
# ['                      pc     beverages              coffee                     ground-coffee                    ']
# ['                      pc     beverages              coffee                     instant-coffee                   ']
# ['                      pc     beverages              health-drink-supplement    ']
# ['                      pc     beverages              health-drink-supplement    kids-5yrs                        ']
# ['                      pc     beverages              health-drink-supplement    children-2-5-yrs                 ']
# ['                      pc     beverages              health-drink-supplement    men-women                        ']
# ['                      pc     beverages              health-drink-supplement    glucose-powder-tablets           ']
# ['                      pc     beverages              fruit-juices-drinks        ']
# ['                      pc     beverages              fruit-juices-drinks        juices-sweetened                 ']
# ['                      pc     beverages              fruit-juices-drinks        unsweetened-cold-press           ']
# ['                      pc     beverages              fruit-juices-drinks        syrups-concentrates              ']
# ['                      pc     snacks-branded-foods   noodle-pasta-vermicelli    ']
# ['                      pc     snacks-branded-foods   noodle-pasta-vermicelli    instant-noodles                  ']
# ['                      pc     snacks-branded-foods   noodle-pasta-vermicelli    hakka-noodles                    ']
# ['                      pc     snacks-branded-foods   noodle-pasta-vermicelli    instant-pasta                    ']
# ['                      pc     snacks-branded-foods   noodle-pasta-vermicelli    vermicelli                       ']
# ['                      pc     snacks-branded-foods   noodle-pasta-vermicelli    cup-noodles                      ']
# ['                      pc     snacks-branded-foods   noodle-pasta-vermicelli    pasta-macaroni                   ']
# ['                      pc     snacks-branded-foods   breakfast-cereals          ']
# ['                      pc     snacks-branded-foods   breakfast-cereals          kids-cereal                      ']
# ['                      pc     snacks-branded-foods   breakfast-cereals          oats-porridge                    ']
# ['                      pc     snacks-branded-foods   breakfast-cereals          muesli                           ']
# ['                      pc     snacks-branded-foods   breakfast-cereals          flakes                           ']
# ['                      pc     snacks-branded-foods   breakfast-cereals          granola-cereal-bars              ']
# ['                      pc     snacks-branded-foods   biscuits-cookies           ']
# ['                      pc     snacks-branded-foods   biscuits-cookies           marie-health-digestive           ']
# ['                      pc     snacks-branded-foods   biscuits-cookies           cream-biscuits-wafers            ']
# ['                      pc     snacks-branded-foods   biscuits-cookies           glucose-milk-biscuits            ']
# ['                      pc     snacks-branded-foods   biscuits-cookies           salted-biscuits                  ']
# ['                      pc     snacks-branded-foods   biscuits-cookies           cookies                          ']
# ['                      pc     snacks-branded-foods   frozen-veggies-snacks      ']
# ['                      pc     snacks-branded-foods   frozen-veggies-snacks      frozen-vegetables                ']
# ['                      pc     snacks-branded-foods   frozen-veggies-snacks      frozen-veg-snacks                ']
# ['                      pc     snacks-branded-foods   frozen-veggies-snacks      frozen-non-veg-snacks            ']
# ['                      pc     snacks-branded-foods   frozen-veggies-snacks      frozen-indian-breads             ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     honey                            ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     tomato-ketchup-sauces            ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     choco-nut-spread                 ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     mayonnaise                       ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     jam-conserve-marmalade           ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     chilli-soya-sauce                ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     vinegar                          ']
# ['                      pc     snacks-branded-foods   spreads-sauces-ketchup     dips-dressings                   ']
# ['                      pc     snacks-branded-foods   snacks-namkeen             ']
# ['                      pc     snacks-branded-foods   snacks-namkeen             chips-corn-snacks                ']
# ['                      pc     snacks-branded-foods   snacks-namkeen             namkeen-savoury-snacks           ']
# ['                      pc     snacks-branded-foods   ready-to-cook-eat          ']
# ['                      pc     snacks-branded-foods   ready-to-cook-eat          breakfast-snack-mixes            ']
# ['                      pc     snacks-branded-foods   ready-to-cook-eat          soups                            ']
# ['                      pc     snacks-branded-foods   ready-to-cook-eat          papads-ready-to-fry              ']
# ['                      pc     snacks-branded-foods   ready-to-cook-eat          home-baking                      ']
# ['                      pc     snacks-branded-foods   ready-to-cook-eat          dessert-mixes                    ']
# ['                      pc     snacks-branded-foods   ready-to-cook-eat          heat-eat-ready-meals             ']
# ['                      pc     snacks-branded-foods   ready-to-cook-eat          canned-food                      ']
# ['                      pc     snacks-branded-foods   chocolates-candies         ']
# ['                      pc     snacks-branded-foods   chocolates-candies         chocolates                       ']
# ['                      pc     snacks-branded-foods   chocolates-candies         toffee-candy-lollypop            ']
# ['                      pc     snacks-branded-foods   chocolates-candies         mints-chewing-gum                ']
# ['                      pc     snacks-branded-foods   chocolates-candies         gift-boxes                       ']
# ['                      pc     snacks-branded-foods   pickles-chutney            ']
# ['                      pc     snacks-branded-foods   pickles-chutney            lime-mango-pickle                ']
# ['                      pc     snacks-branded-foods   pickles-chutney            other-veg-pickle                 ']
# ['                      pc     snacks-branded-foods   pickles-chutney            chutney-powder                   ']
# ['                      pc     snacks-branded-foods   pickles-chutney            non-veg-pickle                   ']
# ['                      pc     snacks-branded-foods   indian-mithai              ']
# ['                      pc     snacks-branded-foods   indian-mithai              chikki-gajjak                    ']
# ['                      pc     snacks-branded-foods   indian-mithai              tinned-packed-sweets             ']
# ['                      pc     snacks-branded-foods   indian-mithai              fresh-sweets                     ']
# ['                      pc     beauty-hygiene         feminine-hygiene           ']
# ['                      pc     beauty-hygiene         feminine-hygiene           sanitary-napkins                 ']
# ['                      pc     beauty-hygiene         feminine-hygiene           panty-liners                     ']
# ['                      pc     beauty-hygiene         feminine-hygiene           hair-removal                     ']
# ['                      pc     beauty-hygiene         feminine-hygiene           intimate-wash-care               ']
# ['                      pc     beauty-hygiene         feminine-hygiene           tampons-menstrual-cups           ']
# ['                      pc     beauty-hygiene         oral-care                  ']
# ['                      pc     beauty-hygiene         oral-care                  mouthwash                        ']
# ['                      pc     beauty-hygiene         oral-care                  toothpaste                       ']
# ['                      pc     beauty-hygiene         oral-care                  toothbrush                       ']
# ['                      pc     beauty-hygiene         oral-care                  floss-tongue-cleaner             ']
# ['                      pc     beauty-hygiene         bath-hand-wash             ']
# ['                      pc     beauty-hygiene         bath-hand-wash             hand-wash-sanitizers             ']
# ['                      pc     beauty-hygiene         bath-hand-wash             bathing-bars-soaps               ']
# ['                      pc     beauty-hygiene         bath-hand-wash             shower-gel-body-wash             ']
# ['                      pc     beauty-hygiene         bath-hand-wash             talcum-powder                    ']
# ['                      pc     beauty-hygiene         bath-hand-wash             bathing-accessories              ']
# ['                      pc     beauty-hygiene         bath-hand-wash             bath-salts-oils                  ']
# ['                      pc     beauty-hygiene         bath-hand-wash             body-scrubs-exfoliants           ']
# ['                      pc     beauty-hygiene         health-medicine            ']
# ['                      pc     beauty-hygiene         health-medicine            antiseptics-bandages             ']
# ['                      pc     beauty-hygiene         health-medicine            everyday-medicine                ']
# ['                      pc     beauty-hygiene         health-medicine            cotton-ear-buds                  ']
# ['                      pc     beauty-hygiene         health-medicine            slimming-products                ']
# ['                      pc     beauty-hygiene         health-medicine            sexual-wellness                  ']
# ['                      pc     beauty-hygiene         health-medicine            supplements-proteins             ']
# ['                      pc     beauty-hygiene         health-medicine            adult-diapers                    ']
# ['                      pc     beauty-hygiene         health-medicine            ayurveda                         ']
# ['                      pc     beauty-hygiene         hair-care                  ']
# ['                      pc     beauty-hygiene         hair-care                  hair-oil-serum                   ']
# ['                      pc     beauty-hygiene         hair-care                  shampoo-conditioner              ']
# ['                      pc     beauty-hygiene         hair-care                  hair-color                       ']
# ['                      pc     beauty-hygiene         hair-care                  hair-scalp-treatment             ']
# ['                      pc     beauty-hygiene         hair-care                  hair-styling                     ']
# ['                      pc     beauty-hygiene         hair-care                  dry-shampoo-conditioner          ']
# ['                      pc     beauty-hygiene         hair-care                  tools-accessories                ']
# ['                      pc     beauty-hygiene         mens-grooming              ']
# ['                      pc     beauty-hygiene         mens-grooming              shaving-care                     ']
# ['                      pc     beauty-hygiene         mens-grooming              bath-shower                      ']
# ['                      pc     beauty-hygiene         mens-grooming              face-body                        ']
# ['                      pc     beauty-hygiene         mens-grooming              talc                             ']
# ['                      pc     beauty-hygiene         mens-grooming              hair-care-styling                ']
# ['                      pc     beauty-hygiene         mens-grooming              moustache-beard-care             ']
# ['                      pc     beauty-hygiene         mens-grooming              combos-gift-sets                 ']
# ['                      pc     beauty-hygiene         skin-care                  ']
# ['                      pc     beauty-hygiene         skin-care                  body-care                        ']
# ['                      pc     beauty-hygiene         skin-care                  face-care                        ']
# ['                      pc     beauty-hygiene         skin-care                  lip-care                         ']
# ['                      pc     beauty-hygiene         skin-care                  eye-care                         ']
# ['                      pc     beauty-hygiene         skin-care                  aromatherapy                     ']
# ['                      pc     beauty-hygiene         fragrances-deos            ']
# ['                      pc     beauty-hygiene         fragrances-deos            womens-deodorants                ']
# ['                      pc     beauty-hygiene         fragrances-deos            mens-deodorants                  ']
# ['                      pc     beauty-hygiene         fragrances-deos            perfume                          ']
# ['                      pc     beauty-hygiene         fragrances-deos            body-sprays-mists                ']
# ['                      pc     beauty-hygiene         fragrances-deos            eau-de-parfum                    ']
# ['                      pc     beauty-hygiene         fragrances-deos            eau-de-toilette                  ']
# ['                      pc     beauty-hygiene         fragrances-deos            attar                            ']
# ['                      pc     beauty-hygiene         fragrances-deos            gift-sets                        ']
# ['                      pc     beauty-hygiene         fragrances-deos            eau-de-cologne                   ']
# ['                      pc     beauty-hygiene         makeup                     ']
# ['                      pc     beauty-hygiene         makeup                     nails                            ']
# ['                      pc     beauty-hygiene         makeup                     lips                             ']
# ['                      pc     beauty-hygiene         makeup                     eyes                             ']
# ['                      pc     beauty-hygiene         makeup                     face                             ']
# ['                      pc     beauty-hygiene         makeup                     makeup-accessories               ']
# ['                      pc     beauty-hygiene         makeup                     makeup-kits-gift-sets            ']
# ['                      pc     cleaning-household     detergents-dishwash        ']
# ['                      pc     cleaning-household     detergents-dishwash        dishwash-liquids-pastes          ']
# ['                      pc     cleaning-household     detergents-dishwash        detergent-powder-liquid          ']
# ['                      pc     cleaning-household     detergents-dishwash        dishwash-bars-powders            ']
# ['                      pc     cleaning-household     detergents-dishwash        detergent-bars                   ']
# ['                      pc     cleaning-household     detergents-dishwash        fabric-pre-post-wash             ']
# ['                      pc     cleaning-household     all-purpose-cleaners       ']
# ['                      pc     cleaning-household     all-purpose-cleaners       toilet-cleaners                  ']
# ['                      pc     cleaning-household     all-purpose-cleaners       kitchen-glass-drain              ']
# ['                      pc     cleaning-household     all-purpose-cleaners       floor-other-cleaners             ']
# ['                      pc     cleaning-household     all-purpose-cleaners       metal-furniture-cleaner          ']
# ['                      pc     cleaning-household     all-purpose-cleaners       imported-cleaners                ']
# ['                      pc     cleaning-household     disposables-garbage-bag    ']
# ['                      pc     cleaning-household     disposables-garbage-bag    kitchen-rolls                    ']
# ['                      pc     cleaning-household     disposables-garbage-bag    garbage-bags                     ']
# ['                      pc     cleaning-household     disposables-garbage-bag    toilet-paper                     ']
# ['                      pc     cleaning-household     disposables-garbage-bag    wet-wipe-pocket-tissues          ']
# ['                      pc     cleaning-household     disposables-garbage-bag    aluminium-foil-clingwrap         ']
# ['                      pc     cleaning-household     disposables-garbage-bag    paper-napkin-tissue-box          ']
# ['                      pc     cleaning-household     fresheners-repellents      ']
# ['                      pc     cleaning-household     fresheners-repellents      mosquito-repellent               ']
# ['                      pc     cleaning-household     fresheners-repellents      insect-repellent                 ']
# ['                      pc     cleaning-household     fresheners-repellents      air-freshener                    ']
# ['                      pc     cleaning-household     mops-brushes-scrubs        ']
# ['                      pc     cleaning-household     mops-brushes-scrubs        utensil-scrub-pad-glove          ']
# ['                      pc     cleaning-household     mops-brushes-scrubs        brooms-dust-pans                 ']
# ['                      pc     cleaning-household     mops-brushes-scrubs        dust-cloth-wipes                 ']
# ['                      pc     cleaning-household     mops-brushes-scrubs        mops-wipers                      ']
# ['                      pc     cleaning-household     mops-brushes-scrubs        toilet-other-brushes             ']
# ['                      pc     cleaning-household     pooja-needs                ']
# ['                      pc     cleaning-household     pooja-needs                camphor-wicks                    ']
# ['                      pc     cleaning-household     pooja-needs                agarbatti-incense-sticks         ']
# ['                      pc     cleaning-household     pooja-needs                lamp-lamp-oil                    ']
# ['                      pc     cleaning-household     pooja-needs                candles-match-box                ']
# ['                      pc     cleaning-household     pooja-needs                other-pooja-needs                ']
# ['                      pc     cleaning-household     pooja-needs                pooja-thali-bells                ']
# ['                      pc     cleaning-household     stationery                 ']
# ['                      pc     cleaning-household     stationery                 electronic-accessories           ']
# ['                      pc     cleaning-household     stationery                 scissor-glue-tape                ']
# ['                      pc     cleaning-household     stationery                 colours-crayons                  ']
# ['                      pc     cleaning-household     stationery                 pen-pencils                      ']
# ['                      pc     cleaning-household     stationery                 notebooks-files-folders          ']
# ['                      pc     cleaning-household     stationery                 erasers-sharpeners               ']
# ['                      pc     cleaning-household     stationery                 exam-pads-pencil-box             ']
# ['                      pc     cleaning-household     stationery                 games-calculators                ']
# ['                      pc     cleaning-household     bins-bathroom-ware         ']
# ['                      pc     cleaning-household     bins-bathroom-ware         hangers-clips-rope               ']
# ['                      pc     cleaning-household     bins-bathroom-ware         dustbins                         ']
# ['                      pc     cleaning-household     bins-bathroom-ware         buckets-mugs                     ']
# ['                      pc     cleaning-household     bins-bathroom-ware         laundry-storage-baskets          ']
# ['                      pc     cleaning-household     bins-bathroom-ware         bath-stool-basin-sets            ']
# ['                      pc     cleaning-household     bins-bathroom-ware         soap-cases-dispensers            ']
# ['                      pc     cleaning-household     bins-bathroom-ware         other-plastic-ware               ']
# ['                      pc     cleaning-household     party-festive-needs        ']
# ['                      pc     cleaning-household     party-festive-needs        gift-wraps-bags                  ']
# ['                      pc     cleaning-household     party-festive-needs        disposable-cups-plates           ']
# ['                      pc     cleaning-household     party-festive-needs        caps-balloons-candles            ']
# ['                      pc     cleaning-household     party-festive-needs        rakhi                            ']
# ['                      pc     cleaning-household     party-festive-needs        decorations                      ']
# ['                      pc     cleaning-household     party-festive-needs        seasonal-accessories             ']
# ['                      pc     cleaning-household     party-festive-needs        holi-colours-pichkari            ']
# ['                      pc     cleaning-household     party-festive-needs        gifts                            ']
# ['                      pc     cleaning-household     car-shoe-care              ']
# ['                      pc     cleaning-household     car-shoe-care              shoe-polish                      ']
# ['                      pc     cleaning-household     car-shoe-care              shoe-shiners-brushes             ']
# ['                      pc     cleaning-household     car-shoe-care              car-freshener                    ']
# ['                      pc     cleaning-household     car-shoe-care              car-polish-cleaners              ']
# ['                      pc     kitchen-garden-pets    appliances-electricals     ']
# ['                      pc     kitchen-garden-pets    appliances-electricals     battery-electrical               ']
# ['                      pc     kitchen-garden-pets    appliances-electricals     cfl-led-bulbs                    ']
# ['                      pc     kitchen-garden-pets    pet-food-accessories       ']
# ['                      pc     kitchen-garden-pets    pet-food-accessories       pet-meals-treats                 ']
# ['                      pc     kitchen-garden-pets    pet-food-accessories       pet-cleaning-grooming            ']
# ['                      pc     kitchen-garden-pets    pet-food-accessories       pet-feeding-support              ']
# ['                      pc     kitchen-garden-pets    pet-food-accessories       pet-collars-leashes              ']
# ['                      pc     kitchen-garden-pets    pet-food-accessories       pet-toys                         ']
# ['                      pc     kitchen-garden-pets    cookware-non-stick         ']
# ['                      pc     kitchen-garden-pets    cookware-non-stick         pressure-cookers                 ']
# ['                      pc     kitchen-garden-pets    cookware-non-stick         gas-stove                        ']
# ['                      pc     kitchen-garden-pets    cookware-non-stick         tawa-sauce-pan                   ']
# ['                      pc     kitchen-garden-pets    cookware-non-stick         kadai-fry-pans                   ']
# ['                      pc     kitchen-garden-pets    cookware-non-stick         cook-and-serve                   ']
# ['                      pc     kitchen-garden-pets    cookware-non-stick         cookware-sets                    ']
# ['                      pc     kitchen-garden-pets    kitchen-accessories        ']
# ['                      pc     kitchen-garden-pets    kitchen-accessories        lighters                         ']
# ['                      pc     kitchen-garden-pets    kitchen-accessories        choppers-graters                 ']
# ['                      pc     kitchen-garden-pets    kitchen-accessories        knives-peelers                   ']
# ['                      pc     kitchen-garden-pets    kitchen-accessories        kitchen-tools-other-accessories  ']
# ['                      pc     kitchen-garden-pets    kitchen-accessories        strainer-ladle-spatula           ']
# ['                      pc     kitchen-garden-pets    gardening                  ']
# ['                      pc     kitchen-garden-pets    gardening                  fertilizers-pesticides           ']
# ['                      pc     kitchen-garden-pets    gardening                  gardening-tools                  ']
# ['                      pc     kitchen-garden-pets    gardening                  pots-planters-trays              ']
# ['                      pc     kitchen-garden-pets    gardening                  seeds-sapling                    ']
# ['                      pc     kitchen-garden-pets    steel-utensils             ']
# ['                      pc     kitchen-garden-pets    steel-utensils             steel-storage-containers         ']
# ['                      pc     kitchen-garden-pets    steel-utensils             plates-tumblers                  ']
# ['                      pc     kitchen-garden-pets    steel-utensils             copper-utensils                  ']
# ['                      pc     kitchen-garden-pets    steel-utensils             bowls-vessels                    ']
# ['                      pc     kitchen-garden-pets    steel-utensils             steel-lunch-boxes                ']
# ['                      pc     kitchen-garden-pets    bakeware                   ']
# ['                      pc     kitchen-garden-pets    bakeware                   bakeware-moulds-cutters          ']
# ['                      pc     kitchen-garden-pets    bakeware                   bakeware-accessories             ']
# ['                      pc     kitchen-garden-pets    bakeware                   baking-tools-brushes             ']
# ['                      pc     kitchen-garden-pets    crockery-cutlery           ']
# ['                      pc     kitchen-garden-pets    crockery-cutlery           glassware                        ']
# ['                      pc     kitchen-garden-pets    crockery-cutlery           cups-mugs-tumblers               ']
# ['                      pc     kitchen-garden-pets    crockery-cutlery           dinner-sets                      ']
# ['                      pc     kitchen-garden-pets    crockery-cutlery           plates-bowls                     ']
# ['                      pc     kitchen-garden-pets    crockery-cutlery           cutlery-spoon-fork               ']
# ['                      pc     kitchen-garden-pets    storage-accessories        ']
# ['                      pc     kitchen-garden-pets    storage-accessories        containers-sets                  ']
# ['                      pc     kitchen-garden-pets    storage-accessories        wall-hooks-hangers               ']
# ['                      pc     kitchen-garden-pets    storage-accessories        water-fridge-bottles             ']
# ['                      pc     kitchen-garden-pets    storage-accessories        racks-holders                    ']
# ['                      pc     kitchen-garden-pets    storage-accessories        umbrella                         ']
# ['                      pc     kitchen-garden-pets    storage-accessories        lunch-boxes                      ']
# ['                      pc     kitchen-garden-pets    storage-accessories        cloth-dryer-iron-table           ']
# ['                      pc     kitchen-garden-pets    flask-casserole            ']
# ['                      pc     kitchen-garden-pets    flask-casserole            vacuum-flask                     ']
# ['                      pc     kitchen-garden-pets    flask-casserole            casserole                        ']
# ['                      pc     eggs-meat-fish         eggs                       ']
# ['                      pc     eggs-meat-fish         eggs                       farm-eggs                        ']
# ['                      pc     eggs-meat-fish         eggs                       country-eggs                     ']
# ['                      pc     eggs-meat-fish         eggs                       protein-eggs                     ']
# ['                      pc     eggs-meat-fish         eggs                       organic-eggs                     ']
# ['                      pc     eggs-meat-fish         eggs                       other-eggs                       ']
# ['                      pc     eggs-meat-fish         poultry                    ']
# ['                      pc     eggs-meat-fish         poultry                    fresh-chicken                    ']
# ['                      pc     eggs-meat-fish         poultry                    frozen-chicken                   ']
# ['                      pc     eggs-meat-fish         poultry                    turkey                           ']
# ['                      pc     eggs-meat-fish         mutton-lamb                ']
# ['                      pc     eggs-meat-fish         mutton-lamb                fresh-mutton                     ']
# ['                      pc     eggs-meat-fish         mutton-lamb                frozen-mutton                    ']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      ']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      pork-ham                         ']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      chicken-sausages                 ']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      turkey-duck                      ']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      lamb                             ']
# ['                      pc     eggs-meat-fish         fish-seafood               ']
# ['                      pc     eggs-meat-fish         fish-seafood               dry-fish                         ']
# ['                      pc     eggs-meat-fish         fish-seafood               frozen-fish-seafood              ']
# ['                      pc     eggs-meat-fish         fish-seafood               prawns-shrimps                   ']
# ['                      pc     eggs-meat-fish         fish-seafood               fresh-fish                       ']
# ['                      pc     eggs-meat-fish         fish-seafood               canned-seafood                   ']
# ['                      pc     eggs-meat-fish         fish-seafood               other-seafood                    ']
# ['                      pc     eggs-meat-fish         pork-other-meats           ']
# ['                      pc     eggs-meat-fish         pork-other-meats           fresh-frozen-pork                ']
# ['                      pc     eggs-meat-fish         marinades                  ']
# ['                      pc     eggs-meat-fish         marinades                  marinated-meat                   ']
# ['                      pc     gourmet-world-food     oils-vinegar               ']
# ['                      pc     gourmet-world-food     oils-vinegar               extra-virgin-olive-oil           ']
# ['                      pc     gourmet-world-food     oils-vinegar               pure-pomace-olive-oil            ']
# ['                      pc     gourmet-world-food     oils-vinegar               regular-white-vinegar            ']
# ['                      pc     gourmet-world-food     oils-vinegar               canola-rapeseed-oil              ']
# ['                      pc     gourmet-world-food     oils-vinegar               balsamic-cider-vinegar           ']
# ['                      pc     gourmet-world-food     oils-vinegar               organic-cold-press-oil           ']
# ['                      pc     gourmet-world-food     oils-vinegar               flavoured-other-oils             ']
# ['                      pc     gourmet-world-food     oils-vinegar               wine-rice-vinegar                ']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     ']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     gourmet-popcorn                  ']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     healthy-baked-snacks             ']
# ...
# ['                      pc     eggs-meat-fish         poultry                    fresh-chicken                    ?nc=cs']
# ['                      pc     eggs-meat-fish         poultry                    frozen-chicken                   ?nc=cs']
# ['                      pc     eggs-meat-fish         poultry                    turkey                           ?nc=cs']
# ['                      pc     eggs-meat-fish         mutton-lamb                ?nc=cs']
# ['                      pc     eggs-meat-fish         mutton-lamb                fresh-mutton                     ?nc=cs']
# ['                      pc     eggs-meat-fish         mutton-lamb                frozen-mutton                    ?nc=cs']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      ?nc=cs']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      pork-ham                         ?nc=cs']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      chicken-sausages                 ?nc=cs']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      turkey-duck                      ?nc=cs']
# ['                      pc     eggs-meat-fish         sausages-bacon-salami      lamb                             ?nc=cs']
# ['                      pc     eggs-meat-fish         fish-seafood               ?nc=cs']
# ['                      pc     eggs-meat-fish         fish-seafood               dry-fish                         ?nc=cs']
# ['                      pc     eggs-meat-fish         fish-seafood               frozen-fish-seafood              ?nc=cs']
# ['                      pc     eggs-meat-fish         fish-seafood               prawns-shrimps                   ?nc=cs']
# ['                      pc     eggs-meat-fish         fish-seafood               fresh-fish                       ?nc=cs']
# ['                      pc     eggs-meat-fish         fish-seafood               canned-seafood                   ?nc=cs']
# ['                      pc     eggs-meat-fish         fish-seafood               other-seafood                    ?nc=cs']
# ['                      pc     eggs-meat-fish         pork-other-meats           ?nc=cs']
# ['                      pc     eggs-meat-fish         pork-other-meats           fresh-frozen-pork                ?nc=cs']
# ['                      pc     eggs-meat-fish         marinades                  ?nc=cs']
# ['                      pc     eggs-meat-fish         marinades                  marinated-meat                   ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               ?nc=cs']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     ?nc=cs']
# ['                      pc     gourmet-world-food     pasta-soup-noodles         ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               ?nc=cs']
# ['                      pc     gourmet-world-food     cereals-breakfast          ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        ?nc=cs']
# ['                      pc     gourmet-world-food     chocolates-biscuits        ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           ?nc=cs']
# ['                      pc     gourmet-world-food     tinned-processed-food      ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               extra-virgin-olive-oil           ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               pure-pomace-olive-oil            ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               regular-white-vinegar            ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               canola-rapeseed-oil              ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               balsamic-cider-vinegar           ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               organic-cold-press-oil           ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               flavoured-other-oils             ?nc=cs']
# ['                      pc     gourmet-world-food     oils-vinegar               wine-rice-vinegar                ?nc=cs']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     ?nc=cs']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     gourmet-popcorn                  ?nc=cs']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     healthy-baked-snacks             ?nc=cs']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     dry-fruits-berries               ?nc=cs']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     nachos-chips                     ?nc=cs']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     roasted-seeds-nuts               ?nc=cs']
# ['                      pc     gourmet-world-food     snacks-dry-fruits-nuts     trail-cocktail-mixes             ?nc=cs']
# ['                      pc     gourmet-world-food     pasta-soup-noodles         ?nc=cs']
# ['                      pc     gourmet-world-food     pasta-soup-noodles         pastas-spaghetti                 ?nc=cs']
# ['                      pc     gourmet-world-food     pasta-soup-noodles         imported-noodles                 ?nc=cs']
# ['                      pc     gourmet-world-food     pasta-soup-noodles         imported-soups                   ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               flavoured-greek-yogurt           ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               tofu                             ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               gourmet-ice-cream                ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               milk-soya-drinks                 ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               international-cheese             ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               cream-cheese-spreads             ?nc=cs']
# ['                      pc     gourmet-world-food     dairy-cheese               butter-cream                     ?nc=cs']
# ['                      pc     gourmet-world-food     cereals-breakfast          ?nc=cs']
# ['                      pc     gourmet-world-food     cereals-breakfast          muesli-rice-cakes                ?nc=cs']
# ['                      pc     gourmet-world-food     cereals-breakfast          imported-oats-porridge           ?nc=cs']
# ['                      pc     gourmet-world-food     cereals-breakfast          cereal-granola-bars              ?nc=cs']
# ['                      pc     gourmet-world-food     cereals-breakfast          gourmet-flakes                   ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        chocolate-peanut-spread          ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        jams-marmalade-spreads           ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        honey-maple-syrup                ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        thai-asian-sauces                ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        mustard-cheese-sauces            ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        salad-dressings                  ?nc=cs']
# ['                      pc     gourmet-world-food     sauces-spreads-dips        hummus-cheese-salsa-dip          ?nc=cs']
# ['                      pc     gourmet-world-food     chocolates-biscuits        ?nc=cs']
# ['                      pc     gourmet-world-food     chocolates-biscuits        crackers-digestive               ?nc=cs']
# ['                      pc     gourmet-world-food     chocolates-biscuits        international-chocolates         ?nc=cs']
# ['                      pc     gourmet-world-food     chocolates-biscuits        luxury-chocolates-gifts          ?nc=cs']
# ['                      pc     gourmet-world-food     chocolates-biscuits        cookies-biscotti-wafer           ?nc=cs']
# ['                      pc     gourmet-world-food     chocolates-biscuits        marshmallow-candy-jelly          ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       cooking-chocolate-cocoa          ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       curry-paste-coconut-milk         ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       exotic-sugar-salt                ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       flours-pre-mixes                 ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       quinoa-grains                    ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       baking-cake-decorations          ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       herbs-seasonings-rubs            ?nc=cs']
# ['                      pc     gourmet-world-food     cooking-baking-needs       baking-accessories               ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           coffee-pre-mix                   ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           health-drinks                    ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           gourmet-tea-tea-bags             ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           gourmet-juices-drinks            ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           cocktail-mixes                   ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           aerated-still-sparkling          ?nc=cs']
# ['                      pc     gourmet-world-food     drinks-beverages           non-alcoholic-beer-wine          ?nc=cs']
# ['                      pc     gourmet-world-food     tinned-processed-food      ?nc=cs']
# ['                      pc     gourmet-world-food     tinned-processed-food      fish-tuna                        ?nc=cs']
# ['                      pc     gourmet-world-food     tinned-processed-food      beans-pulses                     ?nc=cs']
# ['                      pc     gourmet-world-food     tinned-processed-food      olive-jalapeno-gherkin           ?nc=cs']
# ['                      pc     gourmet-world-food     tinned-processed-food      tomatoes-vegetables              ?nc=cs']
# ['                      pc     gourmet-world-food     tinned-processed-food      fruits-pulps                     ?nc=cs']
# ['                      pc     baby-care              baby-food-formula          ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          ?nc=cs']
# ['                      pc     baby-care              diapers-wipes              ?nc=cs']
# ['                      pc     baby-care              mothers-maternity          ?nc=cs']
# ['                      pc     baby-care              feeding-nursing            ?nc=cs']
# ['                      pc     baby-care              baby-accessories           ?nc=cs']
# ['                      pc     baby-care              baby-food-formula          ?nc=cs']
# ['                      pc     baby-care              baby-food-formula          infant-formula                   ?nc=cs']
# ['                      pc     baby-care              baby-food-formula          baby-food                        ?nc=cs']
# ['                      pc     baby-care              baby-food-formula          organic-baby-food                ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-creams-lotions              ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-oil-shampoo                 ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-bath                        ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-laundry                     ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-powder                      ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-oral-care                   ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-health                      ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-buds                        ?nc=cs']
# ['                      pc     baby-care              baby-bath-hygiene          baby-gift-sets                   ?nc=cs']
# ['                      pc     baby-care              diapers-wipes              ?nc=cs']
# ['                      pc     baby-care              diapers-wipes              diapers                          ?nc=cs']
# ['                      pc     baby-care              diapers-wipes              baby-wipes                       ?nc=cs']
# ['                      pc     baby-care              diapers-wipes              nappies-rash-cream               ?nc=cs']
# ['                      pc     baby-care              mothers-maternity          ?nc=cs']
# ['                      pc     baby-care              mothers-maternity          maternity-health-supplements     ?nc=cs']
# ['                      pc     baby-care              mothers-maternity          maternity-personal-care          ?nc=cs']
# ['                      pc     baby-care              feeding-nursing            ?nc=cs']
# ['                      pc     baby-care              feeding-nursing            sippers-bottles                  ?nc=cs']
# ['                      pc     baby-care              feeding-nursing            baby-dishes-utensils             ?nc=cs']
# ['                      pc     baby-care              feeding-nursing            bibs-napkins                     ?nc=cs']
# ['                      pc     baby-care              feeding-nursing            nursing-tools                    ?nc=cs']
# ['                      pc     baby-care              baby-accessories           ?nc=cs']
# ['                      pc     baby-care              baby-accessories           other-baby-accessories           ?nc=cs']
# ['                      pc     baby-care              baby-accessories           soothers-teethers                ?nc=cs']
# ['                      pc     baby-care              baby-accessories           combs-brushes-clippers           ?nc=cs']
# ['                      pc     baby-care              baby-accessories           baby-gear-outdoor                ?nc=cs']
# ['                      pc     baby-care              baby-accessories           baby-toys                        ?nc=cs']
